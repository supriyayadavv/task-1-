# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("D:\\download\\emp.csv",encoding='ISO-8859-1')

# %%
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0    Research & Development  Female      Black   55  04-08-2016     $141,604
# ...

# %%
data.head()
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0  Research & Development  Female      Black   55  04-08-2016     $141,604
# 1           Manufacturing    Male      Asian   59  11/29/1997      $99,975
# 2     Speciality Products  Female  Caucasian   50  10/26/2006     $163,099
# 3           Manufacturing  Female  Caucasian   26   9/27/2019      $84,913
# 4           Manufacturing    Male      Asian   55  11/20/1995      $95,409
#
#   Bonus %        Country       City   Exit Date
# 0     15%  United States    Seattle  10/16/2021
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   Job Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Business Unit  1000 non-null   object
#  5   Gender         1000 non-null   object
#  6   Ethnicity      1000 non-null   object
#  7   Age            1000 non-null   int64
#  8   Hire Date      1000 non-null   object
#  9   Annual Salary  1000 non-null   object
#  10  Bonus %        1000 non-null   object
#  11  Country        1000 non-null   object
#  12  City           1000 non-null   object
#  13  Exit Date      85 non-null     object
# dtypes: int64(1), object(13)
# memory usage: 109.5+ KB

# %%
data.describe()
# Out:
#                Age
# count  1000.000000
# mean     44.382000
# std      11.246981
# min      25.000000
# 25%      35.000000
# 50%      45.000000
# 75%      54.000000
# max      65.000000

# %% [markdown]
# #HISTOGRAM PLOT FOR AGE

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data['Age'], bins=20, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #Box plot for Annual Salary across Departments

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Department', y='Annual Salary', data=data)
plt.title('Annual Salary across Departments')
plt.xlabel('Department')
plt.xticks(rotation=45)  # Rotate x-labels for better readability
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Department', y='Age', data=data)
plt.title('Age Distribution across Departments')
plt.xlabel('Department')
plt.ylabel('Age')
plt.show()

# %%
pivot_table = data.groupby(['Gender', 'Department']).size().unstack().fillna(0)

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', fmt='g')
plt.title('Gender vs Department Co-occurrences')
plt.xlabel('Department')
plt.ylabel('Gender')
plt.show()
